# %% [markdown]
# This document will contain the template and codes for creating master data dictionary , carrying out basic and advanced
# text analytics to prepare training set data be be feeeded into an machine learning supervised model to classify
# product descriptions into multi level multi class classification/categories.

# %% [markdown]
# Creating the Master Data Dictionary of Product Master Classes (Nouns)
# =====================================

# %%
# Importing all necessary libraries
import time
start = time.time()

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import nltk
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict

# %%
# Import the dataset contaning the texts showing mapping between all possible  Noun,Modifier and Characteristic
raw_data_catelogue = pd.read_csv('Master_Dictionary.csv')
raw_data_catelogue.drop_duplicates(subset=None, inplace=True)
raw_data_catelogue = raw_data_catelogue.fillna('NA')

# %%
raw_data_catelogue.head(10)
# Out:
#        Noun Modifier Characteristic  \
# 0  ABRASIVE     AAAA             NA
# 1  ABRASIVE     BELT   BOND/BACKING
# 2  ABRASIVE     BELT   BOND/BACKING
# 3  ABRASIVE     BELT   BOND/BACKING
# 4  ABRASIVE     BELT   BOND/BACKING
# 5  ABRASIVE     BELT   BOND/BACKING
# 6  ABRASIVE     BELT   BOND/BACKING
# 7  ABRASIVE     BELT           GRIT
# 8  ABRASIVE     BELT           GRIT
# 9  ABRASIVE     BELT           GRIT
#
#                                            TheValue
# 0                                                NA
# 1                                         GLUE BOND
# 2                                     RAYON BACKING
# 3                                        RESIN BOND
# 4  RESIN BOND, X-WEIGHT CLOTH BACKING, CLOSE COATED
# 5  RESIN BOND, X-WEIGHT COTTON BACKING, OPEN COATED
# 6                                        WATERPROOF
# 7                                                80
# 8                                               120
# 9                                               180

# %%
import warnings
warnings.filterwarnings('ignore')

defDict = defaultdict(LabelEncoder)
data_dictionary_encoded = raw_data_catelogue.apply(lambda x: defDict[x.name].fit_transform(x))
orig_raw_data_catelogue = data_dictionary_encoded.apply(lambda x: defDict[x.name].inverse_transform(x))

# %%
orig_raw_data_catelogue.head(10)
# Out:
#        Noun Modifier Characteristic  \
# 0  ABRASIVE     AAAA             NA
# 1  ABRASIVE     BELT   BOND/BACKING
# 2  ABRASIVE     BELT   BOND/BACKING
# 3  ABRASIVE     BELT   BOND/BACKING
# 4  ABRASIVE     BELT   BOND/BACKING
# 5  ABRASIVE     BELT   BOND/BACKING
# 6  ABRASIVE     BELT   BOND/BACKING
# 7  ABRASIVE     BELT           GRIT
# 8  ABRASIVE     BELT           GRIT
# 9  ABRASIVE     BELT           GRIT
#
#                                            TheValue
# 0                                                NA
# 1                                         GLUE BOND
# 2                                     RAYON BACKING
# 3                                        RESIN BOND
# 4  RESIN BOND, X-WEIGHT CLOTH BACKING, CLOSE COATED
# 5  RESIN BOND, X-WEIGHT COTTON BACKING, OPEN COATED
# 6                                        WATERPROOF
# 7                                                80
# 8                                               120
# 9                                               180

# %%
data_dictionary_encoded.head()
# Out:
#    Noun  Modifier  Characteristic  TheValue
# 0     0         2             616     15012
# 1     0        54              88     13252
# 2     0        54              88     16157
# 3     0        54              88     16314
# 4     0        54              88     16322

# %%
data_dictionary_mapping = pd.concat([orig_raw_data_catelogue,data_dictionary_encoded], axis=1)
headers=['Noun','Modifier','Characteristic','TheValue','Noun_en','Modifier_en','Characteristic_en','TheValue_en']
data_dictionary_mapping.columns=headers

# %%
data_dictionary_mapping.head()
# Out:
#        Noun Modifier Characteristic  \
# 0  ABRASIVE     AAAA             NA
# 1  ABRASIVE     BELT   BOND/BACKING
# 2  ABRASIVE     BELT   BOND/BACKING
# 3  ABRASIVE     BELT   BOND/BACKING
# 4  ABRASIVE     BELT   BOND/BACKING
#
#                                            TheValue  Noun_en  Modifier_en  \
# 0                                                NA        0            2
# 1                                         GLUE BOND        0           54
# 2                                     RAYON BACKING        0           54
# 3                                        RESIN BOND        0           54
# 4  RESIN BOND, X-WEIGHT CLOTH BACKING, CLOSE COATED        0           54
#
#    Characteristic_en  TheValue_en
# 0                616        15012
# 1                 88        13252
# 2                 88        16157
# 3                 88        16314
# 4                 88        16322

# %%
#Saving the dictionary to a file for reference
data_dictionary_mapping.to_csv('data_dictionary_mapping.csv', sep=',')

# %% [markdown]
# Basic feature extraction using text data
# ========================================

# %%
import re
manufacturer_ref_nr = pd.read_csv('Manufacture_Ref_No.csv',encoding = "latin")
manufacturer_ref_nr.head()
# Out:
#         Manufacturer                       Ref_No  Manufacturer_Name
# 0  MANUFACTURER_NAME                   TAG_NUMBER                SKF
# 1                MFR                 MODEL_NUMBER       BROOK HANSEN
# 2                MFN  MODEL_NUMBER_OR_TYPE_NUMBER            NIKKISO
# 3        Manufacture                           MN                KUK
# 4                OEM                EQPT_MNFR_P_N  FORGE ENGG SYSTEM

# %%
import re
manufacturer_ref_nr = pd.read_csv('Manufacture_Ref_No.csv',encoding = "latin")
manufacturer_ref_nr.head()

def cleaning_input_text(input_text):
    text = re.sub("[,.]", " ", input_text)
    tokens = nltk.word_tokenize(text)
    all_words_bag_temp_1 = nltk.pos_tag(tokens)
    all_words=[]
    for j in range(len(all_words_bag_temp_1)):
        if(all_words_bag_temp_1[j][1] not in ['JJ','MD','PRP','CD','POS','IN'] and all_words_bag_temp_1[j][0].isalpha()):
            all_words.append(all_words_bag_temp_1[j][0])
    clean_text=' '.join(all_words)
    clean_text_1 = clean_text
    del clean_text
    return clean_text_1

def ngram_model(text,n_val,char_value):
    from nltk import ngrams
    sentence = text
    n = n_val
    ngrams = ngrams(sentence.split(), n)
    for grams in ngrams:
        str1 = " ".join(list(grams))
        return_val='NA'
        if (str1.upper() == char_value.upper()):
            return_val=char_value.upper()
            return (return_val)
            break
        else:
            return_val='NA'

def noun_identification(test_sample):
    from nltk import ngrams
    inp = re.sub(r'^\W*','', test_sample)
    inp = re.sub("[)(]",' ', inp)
    inp = re.sub('\W+',' ', inp)
    word_tokens = nltk.word_tokenize(inp.upper())
    noun = inp.split(' ', 1)[0].upper()
    if(noun in data_dictionary_mapping['Noun'].unique()):
        inp_text = ' '.join(word_tokens[:10])
        modifier_list = data_dictionary_mapping[data_dictionary_mapping['Noun'] == noun]['Modifier'].unique()
        for j in modifier_list:
            n_gram = len(j.split())
            modifier_val = ngram_model(inp_text,n_gram,j.upper())
            if (modifier_val != 'NA' and modifier_val is not None):
                dict_noun_modifier = {'noun':noun.upper(),'modifier':modifier_val.upper()}
                return dict_noun_modifier
        if (modifier_val == 'NA' or modifier_val is None):
            dict_noun_modifier = {'noun':noun.upper(),'modifier':'NO MODIFIER'}
            return dict_noun_modifier
    elif (noun not in data_dictionary_mapping['Noun'].unique()):
        noun_val=''
        noun_value=''
        modifier_value=''
        inp_text = word_tokens[:10]
        noun_list= data_dictionary_mapping['Noun'].unique()
        noun_list_str = ' '.join(noun_list)
        for k in inp_text:
            if (re.findall('\\b'+k+'\\b', noun_list_str, flags=re.IGNORECASE)):
                noun_value = str(noun_value) + str(k) + '\n'
        for m in noun_value.split():
            modifier_list = data_dictionary_mapping[data_dictionary_mapping['Noun'] == m]['Modifier'].unique()
            for n in modifier_list:
                if (re.findall('\\b'+n+'\\b', ' '.join(inp_text), flags=re.IGNORECASE)):
                    modifier_value = str(modifier_value) + str(n) + str('\n')
        n_length = len(noun_value.split())
        m_length = len(modifier_value.split())
        if ((n_length > 0) and (m_length>0)):
            dict_noun_modifier = {'noun':noun_value.upper(),'modifier':modifier_value.upper()}
            return dict_noun_modifier
        if ((n_length > 0) and (m_length ==0)):
            dict_noun_modifier = {'noun':noun_value.upper(),'modifier':'NO MODIFIER'}
            return dict_noun_modifier
        if (n_length == 0):
            dict_noun_modifier = {'noun':'NO NOUN','modifier':'NO MODIFIER'}
            return dict_noun_modifier
            
    else:
        dict_noun_modifier = {'noun':'NO NOUN','modifier':'NO MODIFIER'}
        return dict_noun_modifier

def manufacturer(text):
    inp = re.sub("[)(:.]",' ', text).upper()
    manufacturer_tags = manufacturer_ref_nr['Manufacturer'].str.upper().dropna()
    manufacturer_names = manufacturer_ref_nr['Manufacturer_Name'].str.upper().dropna()
    for i in manufacturer_tags:
        if (re.findall('\\b'+i+'\\b', inp, flags=re.IGNORECASE)):
            start_index = inp.index(i)
            word_list = ' '.join(inp[start_index:].split(" ")[0:10])
            for j in manufacturer_names:
                if(re.findall('\\b'+j+'\\b', word_list, flags=re.IGNORECASE)):
                    return(j)

        
# def ref_no(text):
#     inp = text.replace(':',' : ').upper()
#     ref_no_names = manufacturer_ref_nr['Ref_No'].str.upper().dropna()
#     ref_no=''
#     for i in ref_no_names:
#         if ((re.findall('\\b'+i+'\\b', inp, flags=re.IGNORECASE)) and (':' in inp)):
#             start_index = inp.index(i)
#             val = str(inp[start_index:].split(':')[1].strip().rsplit(' ', 1)[0])
#             if (val not in ref_no):
#                 ref_no = str(ref_no) + val + str('\n')
#         elif ((i in inp) and (':' not in inp)):
#             list_of_words = inp.split()
#             if (i in list_of_words):
#                 val1 = str(list_of_words[list_of_words.index(i) + 1])
#                 if (val1 not in ref_no):
#                     ref_no = str(ref_no) + val1 + str('\n')
#     if (len(ref_no)>0):
#         return ref_no
#     else:
#         return 'NA'
def ref_no(text):
    inp = re.sub("[)(:]",' ', text).upper()
    inp_str=inp.split()
    ref_no_names = manufacturer_ref_nr['Ref_No'].str.upper().dropna()
    ref_no=''
    for i in ref_no_names:
        if (re.findall('\\b'+i+'\\b', inp, flags=re.IGNORECASE)):
            #print(i)
            word_list = i.split()
            search = word_list[0]
           #print(search,'--------------->',inp_str)
            if (search in inp_str):
                last_index =inp_str.index(search) + len(word_list)
                if (len(inp_str) > last_index):
                    val = inp_str[inp_str.index(search) + + len(word_list)]
                    if (val not in ref_no):
                        ref_no = str(ref_no) + val + str('\n')
    if (len(ref_no)>0):
        return ref_no
    else:
        return 'NA'

# %%
P = manufacturer('GASKET , SPIRAL WOUND   FILLER MATERIAL GRAPHITE SN : QWEB P/N:ABCD \
PRESSURE RATING 300 LB SIZE 7-1/2 ID X 8-1/2 OD STYLE FLEXITALLIC CG \
THICKNESS 1/16 WINDING MATERIAL INCONEL 600 GASKETS FOR FLANGE SIZES > 24 SHALL CONFORM \
ASME B 16.47 FLANGES UNLESS SPECIFIED OTHERWISE.GASKET  FACE  MUST CLEARLY SHOW SIZE, FLANGE RATING AND MANUFACTURER.\
ANSI 900 LBS.NOM. PIPE SIZE : 3/4 IN')
print(P)
#K = ref_no("DEEP EQPT_MNFR_P_N GROOVE BALL BEARING  P/N SINGLE ROW Part Number : s/abcd xyz SPEC: DIN 625 ISO 15  NO.OF SHIELDS: 1  CAGE MATERIAL: PRESSED STEEL  SIZE: 30MM BORE X 62MM OD  WIDTH/HEIGHT: 16MM    MANUFACTURER: SKF MFR.PART NO 6206Z-C3")
K = ref_no("ACCELEROMETER INTRINSICALLY SAFE RANGE: 1 TO 2000HZ SENSITIVITY: 104.3MV/G BIAS LEVEL: 3.2V FOR PUMP MODEL NO: 12ECR-242 MANUFACTURER: PCB PIEZOTRONICS MFR.MODEL NO: 351M12 MFR.SERIAL NO.3468 / 2961 EQUIPMENT MFR: EBARA EQUIP.MFR.PART NO: 8070143-01")
print(K)
# m = noun_identification('ELECTRIC MOTOR \
# TYPE: INDUCTION INTEGRATED\
# FRAME: ADH-100LB\
# VOLTS: 415V\
# KW: 2.2\
# RPM: 1440\
# MANUFACTURER: BROOK HANSEN\
# MFR.MODEL NO: ADF-100LB"')
# 
# m = noun_identification('ANGULAR  BALL BEARING SIZE: 65MM X 140MM \
# WIDTH/HEIGHT: 33MM \
# CAGE MATERIAL: STEEL \
# TANDEM & SINGLE ASSY \
# SINGLE ROW 1 SET=3PCS \
# FOR CENTRIFUGAL PUMP MANUFACTURER: NTN OR SKF \
# SKF.PART NO: 7313-BECBJ \
# NTN.PART NO: 7313-BDT \
# EQUIPMENT MFR: SHIN NIPPON \
# EQUIP.MODEL NO: 2.5X14SVH-A8 ')
#m=noun_identification('O-RING INSIDE DIAMETER: 196.22MM(7.725IN) OUTSIDE DIAMETER: 210.22MM(8.276IN) THICKNESS: 7.00MM(0.276IN) MATERIAL: VITON DASH NO: 444 HARDNESS: 80 SH A TEMPERATURE RANGE: -20 TO +200°C TYPE: BEWZ19/4000 FOR HEAT EXCHANGER MANUFACTURER: ROBOX MFR.ORIGINAL PART NO: P1602-K03-505 MFR.REVISED PART NO: 3AV71962269B MFR.DRAWING NO: V-2158-207-A-009,POS.NO: 505 EQUIPMENT MFR: ELTACON EQUIP.MODEL NO: 10-K101A-E002 THE ITEM NEEDS TO BE SUPPLIED WITH THE FOLLOWING: -PRODUCTION DATE -EXPIRY DATE -MAXIMUM SHELF LIFE NOTE: THE SUPPLIED ITEM SHOULD HAVE 80% SHELF LIFE')
#m=noun_identification('O-RING INSIDE DIAMETER: 24.99MM(0.984IN) OUTSIDE DIAMETER: 32.05MM(1.262IN) THICKNESS: 3.53MM(0.139IN) DASH NO: 214 FOR BALL VALVE,SIZE: 3IN X 2IN,CL900 VALVE BODY TYPE: SPLIT BODY MANUFACTURER: RING-O-VALVE MFR.ORIGINAL PART NO: 613002400009 MFR.REVISED PART NO: 9F-613002400009 POS.NO: 23 EQUIP.MODEL NO: GBAX2-3-900RTJ EQUIP.SERIAL NO: 96/3789')
#m=noun_identification('FLOATING BALL VALVE BODY MATERIAL: ASTM A216 WCB BALL MATERIAL: SS316 STEM MATERIAL: SS316 SEAT MATERIAL: PTFE BODY SEAL MATERIAL: TFM STEM SEAL MATERIAL: PTFE/TFM PACKING MATERIAL: GRAPHITE+PTFE BOLTING MATERIAL: ASTM A193 B7, A194 2H LIVE LOADED SINGLE PACKING END CONNECTION: THREADED NPTF FACE TO DIMENSION: 114MM OPERATION: HAND LEVER OPERATED MAX.SHUT OFF PRESSURE: 900PSI @ 100°F 100PSI @ 350°F WSP: 150PSI COLD WORKING PRESSURE 2000 INSPECTION AS PER API 598 PIPE THREADS AS PER ANSI B1.20.1 MATERIAL TEST CERTIFICATE: EN 10204-3.1 TO BE SUPPLIED WITH ALL TEST CERTIFICATES VALVE CONSTRUCTION CONFORMS TO MSS SP25 PAINTING SPEC AS PER: RG-S-00-13A0-004 PAINTING SYSTEM NO: 1C AS PER  VALVE SPEC: RG6-S-00-1360-085 PRESSURE RATING: CL150 SIZE: 1IN MANUFACTURER: JAMESBURY (OR) EQUIVALENT MFR.PART NO: 1 A2236TTD EQUIPMENT.MFR: GE EQUIP.MFR.PART NO: 275A8828P002 EQUIP.MODEL NO: MS-6001-B')
#m = noun_identification('@#$%^ FLANGE FOR CONCENTRIC EDGE ORIFICE TAG NO:40352 MODEL RAISED FACE TYPE ORIFICE FLANGE-600 NOMINAL PIPE SIZE:600mm(24"):COMBINE WITH ORIFICE PLATE MODEL:FOR MODEL FOP FLANGE TAP MOUNTING:WELD NECK, FLANGE MATERIAL: CARBON STEEL-150, FLANGE RATING:ANSI CLASS 150-1993,GASKET MATERIAL:NONASBESTOS, BOLT MATERIAL: SNB7G4, NUT MATERIAL:ASTM A193 Gr4/NN, TAP CONNECTION: 1/2 NPT FEMALE, MAKE; NEWFLOW DATA SHEET ATTACHED')
m = noun_identification('GASKET,SPIRAL WOUND,RWI-RJ,2,1500#_____PO TEXT_____FOR REPLACEMENT OF RING JOINT GASKET TYPE                 : SPIRAL WOUND STYLE                : RWI-RJ SIZE                 : 2"""" RATING               : 1500# DESIGN SPECIFICATION : ASME B.16.20 INNER RING MATERIAL  : SS304 FILLER               : GRAPHITE OUTER RING  -        : CARBON STEEL_____CLASS_____GASKET_____CHARACTERISTICS_____   ADDITIONAL_INFORMATION - 1500#   , MAT_GASKET - SOFT IRON   , MAT_GRADE - ASME16.20   , PACKAGE_NUMBER - PEM/113/GEN   , SIZE - 2""""   , TYPE - SPIRAL WOUNDMANUFACTURER INFO: GARLOCK/91311-5102')
print(m)
# Out:
# PIPE
# 8070143-01
# /
# 351M12
#
# {'noun': 'GASKET', 'modifier': 'SPIRAL WOUND'}

# %%
k = ref_no("MOTOR,2.2 KW,400 V,KA57TDV100M4BMG2HF \
MANUFACTURER : HEXAWARE  MODEL_NUMBER_OR_TYPE_NUMBER: MNBVC \
Part Number: QWE \
EQPT_MNFR : ABC PHASE 3 SPEED  1400/47 VOLTAGE 400 SEW-EURODRIVE/KA57TDV100M4BMG2HF")
print(k)
# Out:
# MNBVC
# ABC
# QWE

# %%
def testing_module(choice,test_input):
    if (choice == '1'):
        df_raw_test = pd.read_csv("Test_Data17.csv",encoding = "latin")
        df_raw_test.reset_index(drop=True, inplace=True)
        output_df = pd.DataFrame(columns=['Prod_ID','Material_Desc','Noun','Modifier'])
        counter1=df_raw_test.shape[0]
        
        for i in range(counter1):
            if(i%100 == 0):
                print(i,' Inside 1 if loop')
            prod_id = int(1000 + i)
            noun_modifier_dict = noun_identification(df_raw_test['Long_Desc'][i].replace(',',' '))
            noun_value=noun_modifier_dict['noun'].strip('\n')
            modifier_value = noun_modifier_dict['modifier'].strip('\n')
            concat = noun_value + " | " + modifier_value
            output_df = output_df.append({'Prod_ID':prod_id,'Material_Desc':df_raw_test['Long_Desc'][i],'Noun':noun_value,'Modifier':modifier_value},ignore_index=True)

        out_df_final = pd.DataFrame()
        output_char_value_df_temp = pd.DataFrame()
        df1 = pd.DataFrame()
        counter = df_raw_test.shape[0]
        dummy_data = {'Dummy': [np.NaN]}
        output_char_value_df_dummy = pd.DataFrame(data=dummy_data)
        for i in range(counter):
            if(i%100 == 0):
                print(i,'Inside 2 if loop')
            noun = output_df['Noun'][i].strip('\n')
            modifier = output_df['Modifier'][i].strip('\n')
            char_list = data_dictionary_mapping[(data_dictionary_mapping['Noun'] == noun) & (data_dictionary_mapping['Modifier'] == modifier) ]
            char_values_all = char_list['Characteristic'].unique()
            output_char_value_df = pd.DataFrame(columns=char_values_all)
            if(len(noun.strip().split('\n')) == 1):
                counter1 = len(char_values_all)
                for j in range(counter1):
                    char_value = char_values_all[j]
                    values = char_list[char_list['Characteristic'] == char_value]['TheValue']
                    for k in values:
                        n_gram = len(k.split())
                        char_flag = ngram_model(output_df['Material_Desc'][i],n_gram,k)
                        if char_flag is None:
                            word_list=char_value.split()
                            search = word_list[0]
                            prod_desc=output_df['Material_Desc'][i]
                            clean_string = prod_desc.replace(':', ' ').replace('-', ' ')
                            list_of_words = clean_string.split()
                            if (search in list_of_words):
                                last_index =list_of_words.index(search) + len(word_list)
                                if (len(list_of_words) > last_index):
                                    char_flag = list_of_words[list_of_words.index(search) + len(word_list)]
                                    output_char_value_df=output_char_value_df.append({char_value:char_flag},ignore_index=True)
                        if (char_flag is not None):
                            output_char_value_df=output_char_value_df.append({char_value:char_flag},ignore_index=True)
                        else:
                            output_char_value_df=output_char_value_df.append({char_value:'NA'},ignore_index=True)

                output_char_value_df = output_char_value_df.fillna(method='ffill')
                output_char_value_df = output_char_value_df.tail(1)
            
            if (output_char_value_df.empty):
                col = output_char_value_df_dummy.columns
                for k in range(output_char_value_df_dummy.shape[1]):
                    col_name = col[k]
                    output_char_value_df.loc[0,col_name] = np.NaN
            output_char_value_df_temp = output_char_value_df_temp.append(output_char_value_df)
            output_char_value_df=output_char_value_df.iloc[0:0]
        
        output_char_value_df_temp.reset_index(drop=True, inplace=True)
        output_df.reset_index(drop=True, inplace=True)
        final_output_df = pd.concat([output_df,output_char_value_df_temp],axis=1)
        new = pd.DataFrame()
        new = final_output_df.iloc[:,5:]
        df_temp1 = final_output_df.loc[:,'Prod_ID':'Modifier']
        df = pd.DataFrame()
        
        for i in range(new.shape[0]):
            if(i%100 == 0):
                print(i,'Inside 3 if loop')       
            short_desc=''
            long_desc=''
            val=''
            for j in new.columns:
                val = final_output_df.loc[i,j]
                if (val != 'NA'):
                    if(not pd.isnull(val)):
                        short_desc = str(short_desc) + str(val) + ','
                        long_desc =  str(long_desc) + str(j) + ' : ' + str(val) + '\n'
            df = df.append({'short_description':short_desc,'long_description':long_desc},ignore_index=True)
        
        
        df_formatter=pd.concat([df_temp1,df],axis=1)
        modifier_dict = pd.read_csv('modifier_abbreviation_dict.csv')
        modifier_dict.reset_index(drop=True, inplace=True)
        for i in range(df_formatter.shape[0]):
            if(i%100 == 0):
                print(i,'Inside 4 if loop')
            if(len(df_formatter.loc[i,'Noun'].split('\n')) == 1):
                new_long_desc = "*** " + str(df_formatter.loc[i,'Noun'].strip('\n')) + ' , ' + str(df_formatter.loc[i,'Modifier'].strip('\n')) + " *** " + '\n\n' + str(df_formatter.loc[i,'long_description'])
                modi_search = df_formatter.loc[i,'Modifier']
                if(modi_search in list(modifier_dict['Modifier'])):
                    short_modifier =modifier_dict[modifier_dict['Modifier'] == modi_search ]['Abbreviation'].values[0]
                    new_short_desc =  str(df_formatter.loc[i,'Noun']) + ' , ' + str(short_modifier) + ': ' + str(df_formatter.loc[i,'short_description'])
                    new_short_desc = new_short_desc[:-1]
                else:
                    new_short_desc = str(df_formatter.loc[i,'Noun'].strip('\n')) + ',' + str(df_formatter.loc[i,'Modifier'].strip('\n')) + ':' + str(df_formatter.loc[i,'short_description'])
                    new_short_desc = new_short_desc[:-1]
                df_formatter.loc[i,'long_description'] = new_long_desc
                df_formatter.loc[i,'short_description'] = new_short_desc
        
        df_exception = pd.DataFrame()
        df_manufacture = pd.DataFrame()
        df_ref_no = pd.DataFrame()
        manufacturer_ref_no_tags= ' '.join(manufacturer_ref_nr['Manufacturer'].append(manufacturer_ref_nr['Ref_No']).dropna())
        for k in range(counter):
            if(k%100 == 0):
                print(k,'Inside 5 if loop')
            #Manufacturer
            manufacturer_val = manufacturer(final_output_df.loc[k,'Material_Desc'])
            if (manufacturer_val != 'NA' and manufacturer_val is not None):
                df_manufacture = df_manufacture.append({'Manufacturer': manufacturer_val},ignore_index=True)
            else:
                df_manufacture = df_manufacture.append({'Manufacturer': 'NA'},ignore_index=True)

            ref_no_val = ref_no(final_output_df.loc[k,'Material_Desc'])
            if (ref_no_val != 'NA' and ref_no_val is not None):
                df_ref_no = df_ref_no.append({'Ref_no': ref_no_val},ignore_index=True)
            else:
                df_ref_no = df_ref_no.append({'Ref_no': 'NA'},ignore_index=True)

            #Exception

            mat_desc=df_temp1.loc[k,'Material_Desc'].replace(',',' ') 
            meaningful_text = df_formatter.loc[k,'long_description'] + ' ' + str(df_manufacture.loc[k,'Manufacturer']) + ' ' + str(df_ref_no.loc[k,'Ref_no']) + ' ' + manufacturer_ref_no_tags
            meaningful_text = meaningful_text.upper()
            exception = [w.upper() for w in nltk.word_tokenize(mat_desc) if w not in nltk.word_tokenize(meaningful_text)]
            exception = ' '.join(exception)
            if (len(exception)>0):
                df_exception = df_exception.append({'exception': exception},ignore_index=True)
            else:
                df_exception = df_exception.append({'exception': 'No exception found'},ignore_index=True)
            
        output_dataframe=pd.DataFrame()
        new_output_df=pd.DataFrame()
        new_output_df=final_output_df.iloc[:,4:]
        output_dataframe = pd.concat([df_formatter,df_manufacture,df_ref_no,df_exception,new_output_df],axis=1)
        if ('Dummy' in output_dataframe.columns):
            output_dataframe.drop(['Dummy'],axis=1,inplace=True)
        output_dataframe.to_csv('final_output_df_file_import17.csv')
        display(output_dataframe)
        print('Please check you local file system for output generated : File ----> final_output_df_file_import17.csv')
        return output_dataframe

# %%
# import warnings
warnings.filterwarnings('ignore')

import time
start = time.time()

choice = input("Enter choice(1/2):")
if choice == '1':
    print('Make sure you have feeded your input in the Test_Data.csv')
    test_input=''
    pred_output_df = pd.DataFrame()
    pred_output_df = testing_module(choice,test_input.upper())
if choice == '2':
    #test_input = input('Enter your test sample\n')
    test_input = "SPIRAL WOUND GASKET SIZE: 1""X 900/1500 LBS;WITH EXTERNAL GUIDE RING (STYLE-CG), WINDING MATERIAL:316L FILLER MATERIAL GRAPHITE AS PER ASME B 16.20 TO FIT FOR ANSI B 16.5 FLANGES"
    pred_output_df = testing_module(choice,test_input.upper())
    #display(pred_output_df)
end = time.time()
temp = end-start
hours = temp//3600
temp = temp - 3600*hours
minutes = temp//60
seconds = temp - 60*minutes
print(hours,':',minutes,':',seconds)
# Out:
# Enter choice(1/2):1
# Make sure you have feeded your input in the Test_Data.csv
# 0  Inside 1 if loop
# 100  Inside 1 if loop
# 200  Inside 1 if loop
# 300  Inside 1 if loop
# 400  Inside 1 if loop
# 500  Inside 1 if loop
# 600  Inside 1 if loop
# 700  Inside 1 if loop
# 800  Inside 1 if loop
# 900  Inside 1 if loop
# 1000  Inside 1 if loop
# 1100  Inside 1 if loop
# 1200  Inside 1 if loop
# 1300  Inside 1 if loop
# 1400  Inside 1 if loop
# 1500  Inside 1 if loop
# 1600  Inside 1 if loop
# 1700  Inside 1 if loop
# 1800  Inside 1 if loop
# 1900  Inside 1 if loop
# 2000  Inside 1 if loop
# 2100  Inside 1 if loop
# 2200  Inside 1 if loop
# 2300  Inside 1 if loop
# 2400  Inside 1 if loop
# 2500  Inside 1 if loop
# 2600  Inside 1 if loop
# 2700  Inside 1 if loop
# 2800  Inside 1 if loop
# 2900  Inside 1 if loop
# 3000  Inside 1 if loop
# 3100  Inside 1 if loop
# 3200  Inside 1 if loop
# 3300  Inside 1 if loop
# 3400  Inside 1 if loop
# 3500  Inside 1 if loop
# 3600  Inside 1 if loop
# 3700  Inside 1 if loop
# 3800  Inside 1 if loop
# 3900  Inside 1 if loop
# 4000  Inside 1 if loop
# 4100  Inside 1 if loop
# 4200  Inside 1 if loop
# 4300  Inside 1 if loop
# 4400  Inside 1 if loop
# 4500  Inside 1 if loop
# 4600  Inside 1 if loop
# 4700  Inside 1 if loop
# 4800  Inside 1 if loop
# 4900  Inside 1 if loop
# 0 Inside 2 if loop
# 100 Inside 2 if loop
# 200 Inside 2 if loop
# 300 Inside 2 if loop
# 400 Inside 2 if loop
# 500 Inside 2 if loop
# 600 Inside 2 if loop
# 700 Inside 2 if loop
# 800 Inside 2 if loop
# 900 Inside 2 if loop
# 1000 Inside 2 if loop
# 1100 Inside 2 if loop
# 1200 Inside 2 if loop
# 1300 Inside 2 if loop
# 1400 Inside 2 if loop
# 1500 Inside 2 if loop
# 1600 Inside 2 if loop
# 1700 Inside 2 if loop
# 1800 Inside 2 if loop
# 1900 Inside 2 if loop
# 2000 Inside 2 if loop
# 2100 Inside 2 if loop
# 2200 Inside 2 if loop
# 2300 Inside 2 if loop
# 2400 Inside 2 if loop
# 2500 Inside 2 if loop
# 2600 Inside 2 if loop
# 2700 Inside 2 if loop
# 2800 Inside 2 if loop
# 2900 Inside 2 if loop
# 3000 Inside 2 if loop
# 3100 Inside 2 if loop
# 3200 Inside 2 if loop
# 3300 Inside 2 if loop
# 3400 Inside 2 if loop
# 3500 Inside 2 if loop
# 3600 Inside 2 if loop
# 3700 Inside 2 if loop
# 3800 Inside 2 if loop
# 3900 Inside 2 if loop
# 4000 Inside 2 if loop
# 4100 Inside 2 if loop
# 4200 Inside 2 if loop
# 4300 Inside 2 if loop
# 4400 Inside 2 if loop
# 4500 Inside 2 if loop
# 4600 Inside 2 if loop
# 4700 Inside 2 if loop
# 4800 Inside 2 if loop
# 4900 Inside 2 if loop
# 0 Inside 3 if loop
# 100 Inside 3 if loop
# 200 Inside 3 if loop
# 300 Inside 3 if loop
# 400 Inside 3 if loop
# 500 Inside 3 if loop
# 600 Inside 3 if loop
# 700 Inside 3 if loop
# 800 Inside 3 if loop
# 900 Inside 3 if loop
# 1000 Inside 3 if loop
# 1100 Inside 3 if loop
# 1200 Inside 3 if loop
# 1300 Inside 3 if loop
# 1400 Inside 3 if loop
# 1500 Inside 3 if loop
# 1600 Inside 3 if loop
# 1700 Inside 3 if loop
# 1800 Inside 3 if loop
# 1900 Inside 3 if loop
# 2000 Inside 3 if loop
# 2100 Inside 3 if loop
# 2200 Inside 3 if loop
# 2300 Inside 3 if loop
# 2400 Inside 3 if loop
# 2500 Inside 3 if loop
# 2600 Inside 3 if loop
# 2700 Inside 3 if loop
# 2800 Inside 3 if loop
# 2900 Inside 3 if loop
# 3000 Inside 3 if loop
# 3100 Inside 3 if loop
# 3200 Inside 3 if loop
# 3300 Inside 3 if loop
# 3400 Inside 3 if loop
# 3500 Inside 3 if loop
# 3600 Inside 3 if loop
# 3700 Inside 3 if loop
# 3800 Inside 3 if loop
# 3900 Inside 3 if loop
# 4000 Inside 3 if loop
# 4100 Inside 3 if loop
# 4200 Inside 3 if loop
# 4300 Inside 3 if loop
# 4400 Inside 3 if loop
# 4500 Inside 3 if loop
# 4600 Inside 3 if loop
# 4700 Inside 3 if loop
# 4800 Inside 3 if loop
# 4900 Inside 3 if loop
# 0 Inside 4 if loop
# 100 Inside 4 if loop
# 200 Inside 4 if loop
# 300 Inside 4 if loop
# 400 Inside 4 if loop
# 500 Inside 4 if loop
# 600 Inside 4 if loop
# 700 Inside 4 if loop
# 800 Inside 4 if loop
# 900 Inside 4 if loop
# 1000 Inside 4 if loop
# 1100 Inside 4 if loop
# 1200 Inside 4 if loop
# 1300 Inside 4 if loop
# 1400 Inside 4 if loop
# 1500 Inside 4 if loop
# 1600 Inside 4 if loop
# 1700 Inside 4 if loop
# 1800 Inside 4 if loop
# 1900 Inside 4 if loop
# 2000 Inside 4 if loop
# 2100 Inside 4 if loop
# 2200 Inside 4 if loop
# 2300 Inside 4 if loop
# 2400 Inside 4 if loop
# 2500 Inside 4 if loop
# 2600 Inside 4 if loop
# 2700 Inside 4 if loop
# 2800 Inside 4 if loop
# 2900 Inside 4 if loop
# 3000 Inside 4 if loop
# 3100 Inside 4 if loop
# 3200 Inside 4 if loop
# 3300 Inside 4 if loop
# 3400 Inside 4 if loop
# 3500 Inside 4 if loop
# 3600 Inside 4 if loop
# 3700 Inside 4 if loop
# 3800 Inside 4 if loop
# 3900 Inside 4 if loop
# 4000 Inside 4 if loop
# 4100 Inside 4 if loop
# 4200 Inside 4 if loop
# 4300 Inside 4 if loop
# 4400 Inside 4 if loop
# 4500 Inside 4 if loop
# 4600 Inside 4 if loop
# 4700 Inside 4 if loop
# 4800 Inside 4 if loop
# 4900 Inside 4 if loop
# 0 Inside 5 if loop
# 100 Inside 5 if loop
# 200 Inside 5 if loop
# 300 Inside 5 if loop
# 400 Inside 5 if loop
# 500 Inside 5 if loop
# 600 Inside 5 if loop
# 700 Inside 5 if loop
# 800 Inside 5 if loop
# 900 Inside 5 if loop
# 1000 Inside 5 if loop
# 1100 Inside 5 if loop
# 1200 Inside 5 if loop
# 1300 Inside 5 if loop
# 1400 Inside 5 if loop
# 1500 Inside 5 if loop
# 1600 Inside 5 if loop
# 1700 Inside 5 if loop
# 1800 Inside 5 if loop
# 1900 Inside 5 if loop
# 2000 Inside 5 if loop
# 2100 Inside 5 if loop
# 2200 Inside 5 if loop
# 2300 Inside 5 if loop
# 2400 Inside 5 if loop
# 2500 Inside 5 if loop
# 2600 Inside 5 if loop
# 2700 Inside 5 if loop
# 2800 Inside 5 if loop
# 2900 Inside 5 if loop
# 3000 Inside 5 if loop
# 3100 Inside 5 if loop
# 3200 Inside 5 if loop
# 3300 Inside 5 if loop
# 3400 Inside 5 if loop
# 3500 Inside 5 if loop
# 3600 Inside 5 if loop
# 3700 Inside 5 if loop
# 3800 Inside 5 if loop
# 3900 Inside 5 if loop
# 4000 Inside 5 if loop
# 4100 Inside 5 if loop
# 4200 Inside 5 if loop
# 4300 Inside 5 if loop
# 4400 Inside 5 if loop
# 4500 Inside 5 if loop
# 4600 Inside 5 if loop
# 4700 Inside 5 if loop
# 4800 Inside 5 if loop
# 4900 Inside 5 if loop
#      Prod_ID                                      Material_Desc  \
# 0       1000  MONITOR, SYSTEM 3300/03\nSERIAL DATA INTERFACE...
# 1       1001  40-CONTROL PROCESSOR\nFOR TMR/DCS SYSTEM\nMANU...
# 2       1002  PACKING\nSET OF 2 PIECES\nMATERIAL: GRAPHITE\n...
# 3       1003  ROTOR CONTAINER FOR FRAME 6\nMANUFACTURER: GE\...
# 4       1004  AIR CIRCUIT BREAKER\nAEROMAT\nTYPE: WITHDRAW\n...
# 5       1005  MATERIAL,STUDBOLT: ASTM A193 GR.B7\nMATERIAL,N...
# 6       1006  CURRENT TRANSFORMER\nGS-CT\nRATING: 3A/14.5A\n...
# 7       1007  LINEAR PLUG\nGV03,STD,UN,T/N2.62\nMATERIAL: SU...
# 8       1008  FLAT RING GASKET\nINNER DIAMETER: 39MM\nOUTER ...
# 9       1009  CHECK VALVE\nMANUFACTURER: PARKER\nMFR.PART NO...
# 10      1010  O-RING\nINSIDE DIAMETER: 196.22MM(7.725IN)\nOU...
# 11      1011  AMPLIFIER HANDSET\nFOR CENTRAL PAEAS CABINET\n...
# 12      1012  DC/DC POWER PACK\nT1032-07C\nMANUFACTURER: ABB...
# 13      1013  HP ROTOR ASSEMBLY\nFOR CENTRIFUGAL COMPRESSOR\...
# 14      1014  RELIEF VALVE\nSIZE: 1-1/2IN X 2IN\nTYPE: 307-O...
# 15      1015  PRESSURE GAUGE\nRANGE: 0-7,500PSI\nCASE SIZE: ...
# 16      1016  THERMCOUPLE TUBE CONNECTOR\nMANUFACTURER: GE\n...
# 17      1017  GLASS FUSE\nDIMENSIONS: L 32MM X OD 7MM\nVOLTA...
# 18      1018  GUIDE LINER\n2.5IN STEM(3) P=6610\nMANUFACTURE...
# 19      1019  GASKET\nMANUFACTURER: CATERPILLAR\nMFR.PART NO...
# 20      1020  PACKING,HP/LP\nMANUFACTURER: MASONEILAN\nMFR.P...
# 21      1021  BALL VALVE,\nEND CONNECTION: SOCKET WELD\nBODY...
# 22      1022  MEMBRANE UNIT\nFOR CENTRIFUGAL PUMP\nMANUFACTU...
# 23      1023  SEAT RING\nMATERIAL: F316SS\nMANUFACTURER: RIN...
# 24      1024  IMPELLER SPACER\nMANUFACTURER: NIKKISO\nMFR.PA...
# 25      1025  VALVE CORE\nMATERIAL: ASTM A-216 GR WCC CAST S...
# 26      1026  PRESSURE GAUGE\nRANGE: 0-16BAR\nCASE SIZE: 4-1...
# 27      1027  TRANSFORMER MODULE\nFOR UN-INTERRUPTED POWER S...
# 28      1028  O-RING\nINSIDE DIAMETER: 82.22MM(3.237IN)\nOUT...
# 29      1029  OIL SEAL\nMANUFACTURER: NAK\nMFR.PART NO: 40-7...
# ...      ...                                                ...
# 4969    5969  OVER-LOAD HEATER\nSET OF THREE "3"\nC306-CLASS...
# 4970    5970  DRY GAS SEAL CARTRIDGE,THRUST END\nMANUFACTURE...
# 4971    5971  FILTER WITH 1/8IN NPT FEMALE PORT\nFOR SAMPLIN...
# 4972    5972  STATIC OIL SEAL,BEARING NO.3\nFOR FRAME 7\nMAN...
# 4973    5973  ARM ASSEMBLY\nFOR LH CRANK\nMANUFACTURER: POWE...
# 4974    5974  FLAT RING GASKET\nINNER DIAMETER: 260MM\nOUTER...
# 4975    5975  SPRING COMPLETE WITH 2 WASHERS\nSPRING PART NO...
# 4976    5976  IMPELLER SEAL\nFOR 7TH STAGE\nMANUFACTURER: EL...
# 4977    5977  O-RING\nINSIDE DIAMETER: 189.87MM(7.475IN)\nOU...
# 4978    5978  O-RING\nINSIDE DIAMETER: 59.92MM(2.359IN)\nOUT...
# 4979    5979  COUPLING GRID,\nMANUFACTURER: FALK\nMFR.PART N...
# 4980    5980  BALL BEARING SET\nSET CONTAINS THE FOLLOWING:\...
# 4981    5981  GASKET,METAL REINFORCED GRAPHITE (MRG)\nGASKET...
# 4982    5982  CIRCUIT BREAKER\nRATING: 1P,6A\nM.G: MULTI9 C6...
# 4983    5983  SEAT RING COMPLETE WITH PACKING SET\nSET CONSI...
# 4984    5984  SHAFT\nMANUFACTURER: DOMESTIC MFG\nMFR.PART NO...
# 4985    5985  SPRING COMPLETE WITH 2 WASHERS\nMATERIAL: INCO...
# 4986    5986  COUNTER SUNK,HEX DRIVER\nMATERIAL: CADMIUM PLA...
# 4987    5987  FULL FACE GASKET\nINNER DIAMETER: 150MM\nOUTER...
# 4988    5988  DESCRIPTION: STUDBOLT\nMATERIAL,STUDBOLT: ASTM...
# 4989    5989  TEMPERATURE SWITCH\nCAPILLARY TYPE\nID 26QL-1\...
# 4990    5990  DEEP GROOVE BALL BEARING\nSERIES: 6300\nSINGLE...
# 4991    5991  WATER TEMPERATURE GAUGE\nFOR ENGINE,12V\nRANGE...
# 4992    5992  VALVE REPAIR KIT\nVALVE TYPE: FR2\nSIZE: 1IN\n...
# 4993    5993  BACK-UP RING,SEAT\nMATERIAL: PTFE\nMANUFACTURE...
# 4994    5994  POLYACETAL BUSHING\nMANUFACTURER: KEYSTONE\nMF...
# 4995    5995  FIRST AID KIT\nNORTH 01-00-21A\nMANUFACTURER: ...
# 4996    5996  INBOARD COVER BEARING\nMANUFACTURER: BLACKMER\...
# 4997    5997  PRESSURE GAUGE\nRANGE: 0-0.5IN H20\nCONNECTION...
# 4998    5998  DEEP GROOVE BALL BEARING,\nSINGLE ROW\nNO.OF R...
#
#                                   Noun     Modifier  \
# 0                              MONITOR  NO MODIFIER
# 1           CONTROL\nPROCESSOR\nSYSTEM  NO MODIFIER
# 2                              PACKING  NO MODIFIER
# 3                                ROTOR  NO MODIFIER
# 4            AIR\nCIRCUIT\nBREAKER\nNO      CIRCUIT
# 5                             MATERIAL  NO MODIFIER
# 6                          TRANSFORMER  NO MODIFIER
# 7                  PLUG\nSTD\nMATERIAL  NO MODIFIER
# 8                         RING\nGASKET  NO MODIFIER
# 9                            VALVE\nNO        CHECK
# 10                             O\nRING  NO MODIFIER
# 11                           AMPLIFIER  NO MODIFIER
# 12                         POWER\nPACK  NO MODIFIER
# 13         ROTOR\nASSEMBLY\nCOMPRESSOR  NO MODIFIER
# 14                               VALVE       RELIEF
# 15                  GAUGE\nRANGE\nCASE     PRESSURE
# 16                 TUBE\nCONNECTOR\nNO  NO MODIFIER
# 17                               GLASS  NO MODIFIER
# 18                               GUIDE  NO MODIFIER
# 19                              GASKET  NO MODIFIER
# 20                             PACKING  NO MODIFIER
# 21                                BALL        VALVE
# 22                            MEMBRANE  NO MODIFIER
# 23                                SEAT        VALVE
# 24                            IMPELLER  NO MODIFIER
# 25                               VALVE  NO MODIFIER
# 26                  GAUGE\nRANGE\nCASE     PRESSURE
# 27                         TRANSFORMER  NO MODIFIER
# 28                             O\nRING  NO MODIFIER
# 29                                 OIL  NO MODIFIER
# ...                                ...          ...
# 4969                       HEATER\nSET  NO MODIFIER
# 4970  GAS\nSEAL\nCARTRIDGE\nEND\nCRANE  NO MODIFIER
# 4971                            FILTER  NO MODIFIER
# 4972     OIL\nSEAL\nBEARING\nNO\nFRAME          OIL
# 4973                               ARM  NO MODIFIER
# 4974                      RING\nGASKET  NO MODIFIER
# 4975                            SPRING  NO MODIFIER
# 4976                          IMPELLER  NO MODIFIER
# 4977                           O\nRING  NO MODIFIER
# 4978                           O\nRING  NO MODIFIER
# 4979                          COUPLING  NO MODIFIER
# 4980                              BALL  NO MODIFIER
# 4981                            GASKET  NO MODIFIER
# 4982                           CIRCUIT  NO MODIFIER
# 4983                              SEAT  NO MODIFIER
# 4984                             SHAFT  NO MODIFIER
# 4985                            SPRING  NO MODIFIER
# 4986                           COUNTER  NO MODIFIER
# 4987                      FACE\nGASKET    FULL FACE
# 4988           MATERIAL\nMATERIAL\nNUT  NO MODIFIER
# 4989                     SWITCH\nRANGE  TEMPERATURE
# 4990             BALL\nBEARING\nDESIGN         BALL
# 4991                             WATER  NO MODIFIER
# 4992                             VALVE  NO MODIFIER
# 4993                              BACK  NO MODIFIER
# 4994            BUSHING\nNO\nEQUIPMENT  NO MODIFIER
# 4995              FIRST\nAID\nKIT\nAIR    FIRST AID
# 4996     COVER\nBEARING\nNO\nEQUIPMENT  NO MODIFIER
# 4997                      GAUGE\nRANGE     PRESSURE
# 4998         BALL\nBEARING\nNO\nRUBBER         BALL
#
#                                        long_description  \
# 0                    *** MONITOR , NO MODIFIER *** \n\n
# 1
# 2     *** PACKING , NO MODIFIER *** \n\nMATERIAL : G...
# 3                      *** ROTOR , NO MODIFIER *** \n\n
# 4
# 5                   *** MATERIAL , NO MODIFIER *** \n\n
# 6     *** TRANSFORMER , NO MODIFIER *** \n\nRATING :...
# 7
# 8
# 9
# 10
# 11                 *** AMPLIFIER , NO MODIFIER *** \n\n
# 12
# 13
# 14    *** VALVE , RELIEF *** \n\nINLET CONNECTION : ...
# 15
# 16
# 17                     *** GLASS , NO MODIFIER *** \n\n
# 18                     *** GUIDE , NO MODIFIER *** \n\n
# 19                    *** GASKET , NO MODIFIER *** \n\n
# 20                   *** PACKING , NO MODIFIER *** \n\n
# 21    *** BALL , VALVE *** \n\nMATERIAL : B564\nVALV...
# 22                  *** MEMBRANE , NO MODIFIER *** \n\n
# 23    *** SEAT , VALVE *** \n\nMATERIAL : F316SS\nVA...
# 24                  *** IMPELLER , NO MODIFIER *** \n\n
# 25                     *** VALVE , NO MODIFIER *** \n\n
# 26
# 27    *** TRANSFORMER , NO MODIFIER *** \n\nFREQUENC...
# 28
# 29                       *** OIL , NO MODIFIER *** \n\n
# ...                                                 ...
# 4969
# 4970
# 4971                  *** FILTER , NO MODIFIER *** \n\n
# 4972
# 4973                     *** ARM , NO MODIFIER *** \n\n
# 4974
# 4975                  *** SPRING , NO MODIFIER *** \n\n
# 4976                *** IMPELLER , NO MODIFIER *** \n\n
# 4977
# 4978
# 4979                *** COUPLING , NO MODIFIER *** \n\n
# 4980                    *** BALL , NO MODIFIER *** \n\n
# 4981  *** GASKET , NO MODIFIER *** \n\nMATERIAL : GA...
# 4982  *** CIRCUIT , NO MODIFIER *** \n\nRATING : 1P,...
# 4983        *** SEAT , NO MODIFIER *** \n\nSIZE : 3IN\n
# 4984                   *** SHAFT , NO MODIFIER *** \n\n
# 4985  *** SPRING , NO MODIFIER *** \n\nMATERIAL : IN...
# 4986                 *** COUNTER , NO MODIFIER *** \n\n
# 4987
# 4988
# 4989
# 4990
# 4991                   *** WATER , NO MODIFIER *** \n\n
# 4992  *** VALVE , NO MODIFIER *** \n\nSIZE : 1IN\nTY...
# 4993   *** BACK , NO MODIFIER *** \n\nMATERIAL : PTFE\n
# 4994
# 4995
# 4996
# 4997
# 4998
#
#                                      short_description       Manufacturer  \
# 0                                    MONITOR , NO MOD:        ELECTROMACH
# 1                                                                 FOXBORO
# 2                           PACKING , NO MOD: GRAPHITE               KITZ
# 3                                      ROTOR , NO MOD:                 GE
# 4                                                                   HOLEC
# 5                                   MATERIAL , NO MOD:                 NA
# 6                       TRANSFORMER , NO MOD: 3A/14.5A             POWELL
# 7                                                                    KITZ
# 8                                                              FLOWTRONEX
# 9                                                             CATERPILLAR
# 10                                                                  ROBOX
# 11                                 AMPLIFIER , NO MOD:        GAI-TRONICS
# 12                                                                    ABB
# 13                                                          DEMAG DELAVAL
# 14      VALVE , RLF: 1/2IN,1/2IN,NPTF,NPTF,165PSIG,307             CROSBY
# 15                                                      DOOLEY TACKABERRY
# 16                                                                     GE
# 17                                     GLASS , NO MOD:                 GE
# 18                                     GUIDE , NO MOD:         YKV-VALTEK
# 19                                    GASKET , NO MOD:        CATERPILLAR
# 20                                   PACKING , NO MOD:      DEMAG DELAVAL
# 21    BALL , VLV: B564,NO.901077020002,NO.901077020002       RING-O-VALVE
# 22                                  MEMBRANE , NO MOD:           FLEXIBOX
# 23                            SEAT , VLV: F316SS,NO,NO       RING-O-VALVE
# 24                                  IMPELLER , NO MOD:            NIKKISO
# 25                                     VALVE , NO MOD:              ORBIT
# 26                                                                   WIKA
# 27          TRANSFORMER , NO MOD: 50Hz,EQUIPMENT,3,PEW              GUTOR
# 28                                                                   BOTT
# 29                                       OIL , NO MOD:      SCHAT-HARDING
# ...                                                ...                ...
# 4969                                                               POWELL
# 4970                                                           JOHN CRANE
# 4971                                  FILTER , NO MOD:       STORK KETELS
# 4972                                                                   GE
# 4973                                     ARM , NO MOD:             POWELL
# 4974                                                                ADAMS
# 4975                                  SPRING , NO MOD:             CROSBY
# 4976                                IMPELLER , NO MOD:              EBARA
# 4977                                                          YARWAY CORP
# 4978                                                          SHIN NIPPON
# 4979                                COUPLING , NO MOD:        NAT-OILWELL
# 4980                                    BALL , NO MOD:          HOLZHAUER
# 4981                GASKET , NO MOD: GASKET,CLASS,50IN                 NA
# 4982                           CIRCUIT , NO MOD: 1P,6A            FOXBORO
# 4983                                SEAT , NO MOD: 3IN             IONICS
# 4984                                   SHAFT , NO MOD:      UNION SERVICE
# 4985                          SPRING , NO MOD: INCONEL             CROSBY
# 4986                                 COUNTER , NO MOD:                ITT
# 4987                                                                  MHI
# 4988                                                                   NA
# 4989                                                                   GE
# 4990                                                         BROOK HANSEN
# 4991                                   WATER , NO MOD:                VDO
# 4992                           VALVE , NO MOD: 1IN,FR2              ADLER
# 4993                               BACK , NO MOD: PTFE       RING-O-VALVE
# 4994                                                              VANESSA
# 4995                                                         AIR PRODUCTS
# 4996                                                       BEST EQUIPMENT
# 4997                                                                DWYER
# 4998                                                       BEST EQUIPMENT
#
#                                         Ref_no  \
# 0                              3300/03-03-00\n
# 1                                    P0960JA\n
# 2                                  977118-01\n
# 3                                    7C86J61\n
# 4                                    3309002\n
# 5                                           NA
# 6                                    GFM-200\n
# 7                         001949.157.0008057\n
# 8                          617A0620001T51000\n
# 9                         3-283-2-G5\n4W8761\n
# 10                                          NA
# 11                                          NA
# 12                               HIER-466688\n
# 13                                 520142-15\n
# 14                                 981105-MD\n
# 15                                    M2269N\n
# 16                              287A1399P021\n
# 17                                  P13-5712\n
# 18                            009458-842-000\n
# 19                                    8N1996\n
# 20                                   5675810\n
# 21                        EQUIP.MANUFACTURER\n
# 22                            7908-1200-4723\n
# 23                              F004R8AD00$5\n
# 24                                       POS\n
# 25                                          NA
# 26                                          NA
# 27                                          NA
# 28                                 25154-152\n
# 29                                   40-72-7\n
# ...                                        ...
# 4969                                H2013B-3\n
# 4970                        1317/28AT/S39691\n
# 4971                           SS-4TF-F2-140\n
# 4972                            201C7968G001\n
# 4973                               50924-G1P\n
# 4974                             31314220WC0\n
# 4975                           X09822/122568\n
# 4976                             E9180155-16\n
# 4977                               110056-A7\n
# 4978                           0000-229-9509\n
# 4979           MFR.MODEL\nEQUIP.MANUFACTURER\n
# 4980                   84821090\n321/550/1-2\n
# 4981                                        NA
# 4982                                   24972\n
# 4983                               100-030-3\n
# 4984                            1-316X28-916\n
# 4985                           X09406/123374\n
# 4986                              0240-0009J\n
# 4987                                    1058\n
# 4988                                        NA
# 4989  203B3-P135-09-C7A-TTWVX2\n351A9092P002\n
# 4990                                 6307-C3\n
# 4991     V1231015104D\n1234-1250-5\n310-501D\n
# 4992                      FR2-1-GASKETS-PTFE\n
# 4993                            C000Q150K585\n
# 4994                                  71EK44\n
# 4995                           6-493-99-0007\n
# 4996                                   43070\n
# 4997                                  2000-1\n
# 4998                                 6309-LU\n
#
#                                               exception ACTION     ...      \
# 0     SYSTEM 3300/03 SERIAL DATA INTERFACE DYNAMIC D...    NaN     ...
# 1     40-CONTROL PROCESSOR FOR TMR/DCS SYSTEM : : EQ...    NaN     ...
# 2     SET OF 2 PIECES FOR BALL VALVE SIZE 12INX10IN ...    NaN     ...
# 3     CONTAINER FOR FRAME 6 : : EQUIP.MODEL : MS 6001 B    NaN     ...
# 4     AIR CIRCUIT BREAKER AEROMAT TYPE : WITHDRAW OF...    NaN     ...
# 5     STUDBOLT : ASTM A193 GR.B7 NUT : ASTM A194 GR....    NaN     ...
# 6     CURRENT GS-CT ITI POWELL-ELECT EQUIP.MODEL 733...    NaN     ...
# 7     LINEAR PLUG GV03 STD UN T/N2.62 MATERIAL : SUS...    NaN     ...
# 8     FLAT RING GASKET INNER DIAMETER : 39MM OUTER D...    NaN     ...
# 9     CHECK VALVE : PARKER : : : EQUIP.MODEL : CAT-3...    NaN     ...
# 10    O-RING INSIDE DIAMETER : 196.22MM ( 7.725IN ) ...    NaN     ...
# 11    HANDSET FOR CENTRAL PAEAS CABINET : MFR.ORIGIN...    NaN     ...
# 12    DC/DC POWER PACK T1032-07C : : EQUIP.MODEL : W...    NaN     ...
# 13    HP ROTOR ASSEMBLY FOR CENTRIFUGAL COMPRESSOR :...    NaN     ...
# 14    1-1/2IN X 2IN 307-ORF 1-1/2IN-NPTM 2IN-NPTF CA...    NaN     ...
# 15    PRESSURE GAUGE RANGE : 0-7 500PSI CASE SIZE : ...    NaN     ...
# 16    THERMCOUPLE TUBE CONNECTOR : : VENDOR : SUPPLY...    NaN     ...
# 17    FUSE DIMENSIONS : L 32MM X OD 7MM VOLTAGE : 25...    NaN     ...
# 18    LINER 2.5IN STEM ( 3 ) P=6610 : : ORIGINAL PO ...    NaN     ...
# 19         : : : MHD A AL- BAHAR EQUIP.MODEL : CAT-3616    NaN     ...
# 20          HP/LP : MASONEILAN : : EQUIP.MODEL : 06MH6A    NaN     ...
# 21    END CONNECTION SOCKET WELD BODY UNS N08825 TRI...    NaN     ...
# 22    UNIT FOR CENTRIFUGAL PUMP : : : EQUIP.MODEL : ...    NaN     ...
# 23                     RING EQUIP.MODEL GBAA2L-4-900RTJ    NaN     ...
# 24    SPACER : ( ) : 14 MFR.REF.NO : 12M-S22-0002Z01...    NaN     ...
# 25    CORE MATERIAL : ASTM A-216 GR WCC CAST STEEL F...    NaN     ...
# 26    PRESSURE GAUGE RANGE : 0-16BAR CASE SIZE : 4-1...    NaN     ...
# 27    MODULE FOR UN-INTERRUPTED POWER SUPPLY ( UPS )...    NaN     ...
# 28    O-RING INSIDE DIAMETER : 82.22MM ( 3.237IN ) O...    NaN     ...
# 29                  SEAL : NAK : : EQUIP.MODEL : MCB-28    NaN     ...
# ...                                                 ...    ...     ...
# 4969  OVER-LOAD HEATER SET OF THREE `` 3 '' C306-CLA...    NaN     ...
# 4970  DRY GAS SEAL CARTRIDGE THRUST END : ORIGINAL :...    NaN     ...
# 4971  WITH 1/8IN NPT FEMALE PORT FOR SAMPLING NOMINA...    NaN     ...
# 4972  STATIC OIL SEAL BEARING NO.3 FOR FRAME 7 : : E...    NaN     ...
# 4973  ASSEMBLY FOR LH CRANK : ELECTRIC : EQUIP.MODEL...    NaN     ...
# 4974  FLAT RING GASKET INNER DIAMETER : 260MM OUTER ...    NaN     ...
# 4975  COMPLETE WITH 2 WASHERS : X9822 WASHER : 12256...    NaN     ...
# 4976  SEAL FOR 7TH STAGE : ELLIOTT : : EQUIP.MODEL :...    NaN     ...
# 4977  O-RING INSIDE DIAMETER : 189.87MM ( 7.475IN ) ...    NaN     ...
# 4978  O-RING INSIDE DIAMETER : 59.92MM ( 2.359IN ) O...    NaN     ...
# 4979  GRID : FALK NO.0758252 NO.1090T31 : EQUIP.MFR....    NaN     ...
# 4980  BEARING SET SET CONTAINS THE FOLLOWING : 2EA B...    NaN     ...
# 4981  METAL REINFORCED GRAPHITE ( MRG ) DESIGN SPECS...    NaN     ...
# 4982  BREAKER 1P 6A M.G MULTI9 C60H C6 MERLIN GERIN ...    NaN     ...
# 4983  RING COMPLETE WITH PACKING SET SET CONSISTS OF...    NaN     ...
# 4984    : DOMESTIC MFG : : EQUIP.MODEL : 2RCV645-8-WP-1    NaN     ...
# 4985  COMPLETE WITH 2 WASHERS X-750 X09406 WASHER 12...    NaN     ...
# 4986  SUNK HEX DRIVER MATERIAL : CADMIUM PLATED STEE...    NaN     ...
# 4987  FULL FACE GASKET INNER DIAMETER : 150MM OUTER ...    NaN     ...
# 4988  DESCRIPTION : STUDBOLT MATERIAL STUDBOLT : AST...    NaN     ...
# 4989  TEMPERATURE SWITCH CAPILLARY TYPE ID 26QL-1 RA...    NaN     ...
# 4990  DEEP GROOVE BALL BEARING SERIES : 6300 SINGLE ...    NaN     ...
# 4991  TEMPERATURE GAUGE FOR ENGINE 12V RANGE : 40 TO...    NaN     ...
# 4992              REPAIR KIT ORIGINAL PO P-215A-003-A19    NaN     ...
# 4993     BACK-UP RING SEAT EQUIP.MODEL MBAX2-9-5000GEAR    NaN     ...
# 4994  POLYACETAL BUSHING : KEYSTONE : : EQUIP.MODEL ...    NaN     ...
# 4995  FIRST AID KIT NORTH 01-00-21A : : EQUIP.MODEL ...    NaN     ...
# 4996  INBOARD COVER BEARING : BLACKMER : : EQUIP.MOD...    NaN     ...
# 4997  PRESSURE GAUGE RANGE : 0-0.5IN H20 CONNECTION ...    NaN     ...
# 4998  DEEP GROOVE BALL BEARING SINGLE ROW NO.OF RUBB...    NaN     ...
#
#      VOLTAGE VOLUME/CONTAINER WATTAGE WEIGHT WIDTH WINDING MATERIAL WIRE  \
# 0        NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 1        NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 2        NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 3        NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4        NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 5        NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 6        NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 7        NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 8        NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 9        NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 10       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 11       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 12       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 13       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 14       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 15       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 16       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 17       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 18       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 19       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 20       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 21       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 22       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 23       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 24       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 25       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 26       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 27       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 28       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 29       NaN              NaN     NaN    NaN   NaN              NaN  NaN
# ...      ...              ...     ...    ...   ...              ...  ...
# 4969     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4970     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4971     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4972     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4973     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4974     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4975     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4976     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4977     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4978     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4979     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4980     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4981     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4982     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4983     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4984     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4985     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4986     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4987     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4988     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4989     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4990     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4991     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4992     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4993     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4994     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4995     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4996     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4997     NaN              NaN     NaN    NaN   NaN              NaN  NaN
# 4998     NaN              NaN     NaN    NaN   NaN              NaN  NaN
#
#      WIRE DIAMETER WIRE SIZE WORK WEIGHT
# 0              NaN       NaN         NaN
# 1              NaN       NaN         NaN
# 2              NaN       NaN         NaN
# 3              NaN       NaN         NaN
# 4              NaN       NaN         NaN
# 5              NaN       NaN         NaN
# 6              NaN       NaN         NaN
# 7              NaN       NaN         NaN
# 8              NaN       NaN         NaN
# 9              NaN       NaN         NaN
# 10             NaN       NaN         NaN
# 11             NaN       NaN         NaN
# 12             NaN       NaN         NaN
# 13             NaN       NaN         NaN
# 14             NaN       NaN         NaN
# 15             NaN       NaN         NaN
# 16             NaN       NaN         NaN
# 17             NaN       NaN         NaN
# 18             NaN       NaN         NaN
# 19             NaN       NaN         NaN
# 20             NaN       NaN         NaN
# 21             NaN       NaN         NaN
# 22             NaN       NaN         NaN
# 23             NaN       NaN         NaN
# 24             NaN       NaN         NaN
# 25             NaN       NaN         NaN
# 26             NaN       NaN         NaN
# 27             NaN       NaN         NaN
# 28             NaN       NaN         NaN
# 29             NaN       NaN         NaN
# ...            ...       ...         ...
# 4969           NaN       NaN         NaN
# 4970           NaN       NaN         NaN
# 4971           NaN       NaN         NaN
# 4972           NaN       NaN         NaN
# 4973           NaN       NaN         NaN
# 4974           NaN       NaN         NaN
# 4975           NaN       NaN         NaN
# 4976           NaN       NaN         NaN
# 4977           NaN       NaN         NaN
# 4978           NaN       NaN         NaN
# 4979           NaN       NaN         NaN
# 4980           NaN       NaN         NaN
# 4981           NaN       NaN         NaN
# 4982           NaN       NaN         NaN
# 4983           NaN       NaN         NaN
# 4984           NaN       NaN         NaN
# 4985           NaN       NaN         NaN
# 4986           NaN       NaN         NaN
# 4987           NaN       NaN         NaN
# 4988           NaN       NaN         NaN
# 4989           NaN       NaN         NaN
# 4990           NaN       NaN         NaN
# 4991           NaN       NaN         NaN
# 4992           NaN       NaN         NaN
# 4993           NaN       NaN         NaN
# 4994           NaN       NaN         NaN
# 4995           NaN       NaN         NaN
# 4996           NaN       NaN         NaN
# 4997           NaN       NaN         NaN
# 4998           NaN       NaN         NaN
#
# [4999 rows x 250 columns]
# Please check you local file system for output generated : File ----> final_output_df_file_import17.csv
# 2.0 : 13.0 : 34.19738173484802

# %%
# pred_output_df = pred_output_df.sort_values(['Noun','Modifier'], ascending=[True,True])
n_noun_modifier= pd.DataFrame()
n_noun_modifier = pred_output_df.loc[:,'Noun':'Modifier'].drop_duplicates()
n_noun_modifier.reset_index(drop=True, inplace=True)
writer = pd.ExcelWriter('final_output_df_file_import_excel17.xlsx', engine='xlsxwriter')
for i in range(n_noun_modifier.shape[0]):
    noun=n_noun_modifier.loc[i,'Noun'].replace('/','_')
    modifier=n_noun_modifier.loc[i,'Modifier'].replace('/','_')
    df_name = str(noun) + "_" + str(modifier)
    name = n_noun_modifier.loc[i,'Noun'].replace(' ','_').replace('/','_') + "_" + n_noun_modifier.loc[i,'Modifier'].replace(' ','_').replace('/','_')
    name = name[ 0 : 0 + 30]
    df_taxonomy = pd.DataFrame()
    df_taxonomy = pred_output_df[pred_output_df['Noun'] == noun]
    df_taxonomy = df_taxonomy[df_taxonomy['Modifier'] == modifier]
    df_taxonomy.dropna(axis='columns',inplace=True,how='all')
    if ('NA' in df_taxonomy.columns):
        df_taxonomy.drop(['NA'],axis=1,inplace=True)
    df_taxonomy = df_taxonomy.replace('NA','')
    df_taxonomy.reset_index(drop=True, inplace=True)
    df_taxonomy.columns = map(str.upper, df_taxonomy.columns)
    workbook  = writer.book
    for i in range(df_taxonomy.shape[0]):
        if('EXCEPTION' in df_taxonomy.columns):
            col_names_omit=' '.join(df_taxonomy.columns)
            mat_desc = df_taxonomy.loc[i,'EXCEPTION']
            exception = [w.upper() for w in nltk.word_tokenize(mat_desc) if w not in nltk.word_tokenize(col_names_omit)]
            exception = ' '.join(exception)
            df_taxonomy['EXCEPTION']=exception
    df_taxonomy.to_excel(writer,sheet_name=name)
    worksheet = writer.sheets[name]
    start_row = 1
    start_col = 7
    end_row = df_taxonomy.shape[0]
    end_col = df_taxonomy.shape[1]
    format0 = workbook.add_format({'bg_color': '#FFA07A'})
    format1 = workbook.add_format({'bg_color': '#90EE90'})
    format2 = workbook.add_format({'font_color': '#FFFFFF','bg_color': '#0000FF'})
    cell_format = workbook.add_format()
    cell_format.set_align('left')
    cell_format.set_align('top')
    worksheet.conditional_format(1, 0, end_row, end_col, {'type':'blanks', 'format': format0})
    worksheet.conditional_format(start_row, start_col, end_row, end_col, {'type':'no_blanks', 'format': format1})
    worksheet.conditional_format(start_row, start_col, end_row, end_col, {'format': cell_format})
    worksheet.conditional_format(0, 0, 0, end_col, {'type':'no_blanks', 'format': format2})
writer.save()
